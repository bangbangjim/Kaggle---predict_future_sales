# %%
import pandas as pd
import numpy as np
import os 
os.listdir()
# Out:
# ['items.csv',
#  'shops.csv',
#  'sales_train.csv',
#  'EDA.ipynb',
#  'sample_submission.csv',
#  'test.csv',
#  '.ipynb_checkpoints',
#  'item_categories.csv']

# %%
itemsDf = pd.read_csv("items.csv")
itemsDf
# Out:
#                                                item_name  item_id  \
# 0              ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D        0
# 1      !ABBYY FineReader 12 Professional Edition Full...        1
# 2          ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
# 3        ***ГОЛУБАЯ ВОЛНА  (Univ)                      D        3
# 4            ***КОРОБКА (СТЕКЛО)                       D        4
# ...                                                  ...      ...
# 22165             Ядерный титбит 2 [PC, Цифровая версия]    22165
# 22166    Язык запросов 1С:Предприятия  [Цифровая версия]    22166
# 22167  Язык запросов 1С:Предприятия 8 (+CD). Хрустале...    22167
# 22168                                Яйцо для Little Inu    22168
# 22169                      Яйцо дракона (Игра престолов)    22169
#
#        item_category_id
# 0                    40
# 1                    76
# 2                    40
# 3                    40
# 4                    40
# ...

# %%
len(itemsDf.item_name.unique())
# Out:
# 22170

# %%
print ("Number of category:", len(itemsDf.item_category_id.unique()))
itemsDf.item_category_id.value_counts(normalize= True)
# Out:
# Number of category: 84
# 40    0.227109
# 55    0.106676
# 37    0.080289
# 31    0.050744
# 58    0.035634
#         ...
# 50    0.000090
# 1     0.000090
# 51    0.000045
# 10    0.000045
# 79    0.000045
# Name: item_category_id, Length: 84, dtype: float64

# %%
print ("Number of items:", len(itemsDf.item_id.unique()))
itemsDf.item_id.value_counts(ascending= False)
# Out:
# Number of items: 22170
# 2047     1
# 2724     1
# 4759     1
# 19100    1
# 17053    1
#         ..
# 19779    1
# 5448     1
# 7497     1
# 1354     1
# 0        1
# Name: item_id, Length: 22170, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig = plt.figure(figsize =(24,16))
sns.countplot(itemsDf.item_category_id)

# %%
itemsCatDf = pd.read_csv("item_categories.csv")
itemsCatDf
# Out:
#            item_category_name  item_category_id
# 0     PC - Гарнитуры/Наушники                 0
# 1            Аксессуары - PS2                 1
# 2            Аксессуары - PS3                 2
# 3            Аксессуары - PS4                 3
# 4            Аксессуары - PSP                 4
# ..                        ...               ...
# 79                  Служебные                79
# 80         Служебные - Билеты                80
# 81    Чистые носители (шпиль)                81
# 82  Чистые носители (штучные)                82
# 83           Элементы питания                83
#
# [84 rows x 2 columns]

# %%
shopDf = pd.read_csv("shops.csv")
shopDf.head()
# Out:
#                         shop_name  shop_id
# 0   !Якутск Орджоникидзе, 56 фран        0
# 1   !Якутск ТЦ "Центральный" фран        1
# 2                Адыгея ТЦ "Мега"        2
# 3  Балашиха ТРК "Октябрь-Киномир"        3
# 4        Волжский ТЦ "Волга Молл"        4

# %%
shopDf[shopDf.shop_id.isin([0,57])]
# Out:
#                         shop_name  shop_id
# 0   !Якутск Орджоникидзе, 56 фран        0
# 57        Якутск Орджоникидзе, 56       57

# %%
shopDf.shop_name.value_counts()
# Out:
# Томск ТРЦ "Изумрудный Город"                       1
# Москва ТК "Буденовский" (пав.К7)                   1
# Балашиха ТРК "Октябрь-Киномир"                     1
# Казань ТЦ "ПаркХаус" II                            1
# Москва МТРЦ "Афи Молл"                             1
# Н.Новгород ТРЦ "РИО"                               1
# Красноярск ТЦ "Июнь"                               1
# Тюмень ТРЦ "Кристалл"                              1
# Якутск ТЦ "Центральный"                            1
# Казань ТЦ "Бехетле"                                1
# Самара ТЦ "ПаркХаус"                               1
# Сергиев Посад ТЦ "7Я"                              1
# Москва ТЦ "МЕГА Белая Дача II"                     1
# Химки ТЦ "Мега"                                    1
# Москва "Распродажа"                                1
# Коломна ТЦ "Рио"                                   1
# Уфа ТЦ "Семья" 2                                   1
# Тюмень ТЦ "Зеленый Берег"                          1
# ...

# %%
print ("Number of shops:", len(shopDf.shop_id.unique()))
# Out:
# Number of shops: 60

# %% [markdown]
# Just making sure that shop number is in fact 60 by checking the name

# %%
print ("Number of shops:", len(shopDf.shop_name.unique()))
# Out:
# Number of shops: 60

# %%
pd.read_csv("sample_submission.csv").head()
# Out:
#    ID  item_cnt_month
# 0   0             0.5
# 1   1             0.5
# 2   2             0.5
# 3   3             0.5
# 4   4             0.5

# %%
trainDf = pd.read_csv("sales_train.csv")
print (trainDf.columns)
trainDf.head()
# Out:
# Index(['date', 'date_block_num', 'shop_id', 'item_id', 'item_price',
#        'item_cnt_day'],
#       dtype='object')
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154      999.00           1.0
# 1  03.01.2013               0       25     2552      899.00           1.0
# 2  05.01.2013               0       25     2552      899.00          -1.0
# 3  06.01.2013               0       25     2554     1709.05           1.0
# 4  15.01.2013               0       25     2555     1099.00           1.0

# %%
testDf = pd.read_csv("test.csv")
print (len(testDf))
testDf.head()
# Out:
# 214200
#    ID  shop_id  item_id
# 0   0        5     5037
# 1   1        5     5320
# 2   2        5     5233
# 3   3        5     5232
# 4   4        5     5268

# %%
trainDf.item_cnt_day.describe()
# Out:
# count    2.935849e+06
# mean     1.242641e+00
# std      2.618834e+00
# min     -2.200000e+01
# 25%      1.000000e+00
# 50%      1.000000e+00
# 75%      1.000000e+00
# max      2.169000e+03
# Name: item_cnt_day, dtype: float64

# %% [markdown]
# Notice some negative sales above

# %%
print ("Detail of negative sales")
returnDf = trainDf[trainDf.item_cnt_day < 0]
returnDf.describe()
# Out:
# Detail of negative sales
#        date_block_num      shop_id       item_id    item_price  item_cnt_day
# count      7356.00000  7356.000000   7356.000000   7356.000000   7356.000000
# mean         14.63037    32.514546   8982.021207   1442.945623     -1.025150
# std           9.43772    16.825725   6166.315366   2419.680132      0.368794
# min           0.00000     2.000000     28.000000      0.500000    -22.000000
# 25%           7.00000    19.000000   3734.000000    349.000000     -1.000000
# 50%          13.00000    31.000000   6927.000000    799.000000     -1.000000
# 75%          23.00000    47.000000  14056.000000   1699.000000     -1.000000
# max          33.00000    59.000000  22167.000000  33490.000000     -1.000000

# %%
returnDf.item_id.value_counts(ascending=False)
# Out:
# 2331     56
# 3734     41
# 1915     32
# 5672     31
# 4332     27
#          ..
# 6484      1
# 7838      1
# 20764     1
# 1701      1
# 4102      1
# Name: item_id, Length: 3511, dtype: int64

# %%
trainDf.groupby("item_id").item_price.apply(lambda x: len(x.unique())).sort_values(ascending = False)
# Out:
# item_id
# 17717    1601
# 11373     427
# 11369     344
# 11370     335
# 6675      217
#          ...
# 9357        1
# 9360        1
# 9365        1
# 9368        1
# 0           1
# Name: item_price, Length: 21807, dtype: int64

# %% [markdown]
# many item are sold for different prices, even in the same shop on the same date

# %%
trainDf[trainDf.item_id == 17717]
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 5141     11.01.2013               0       25    17717      1099.0
# 8285     16.01.2013               0       19    17717       299.0
# 13890    20.01.2013               0       22    17717       999.0
# 13891    23.01.2013               0       22    17717       399.0
# 13892    31.01.2013               0       22    17717       990.0
# ...             ...             ...      ...      ...         ...
# 2930742  14.10.2015              33       22    17717      2150.0
# 2930743  15.10.2015              33       22    17717      1474.5
# 2930744  16.10.2015              33       22    17717      2150.0
# 2930745  18.10.2015              33       22    17717       999.0
# 2930746  30.10.2015              33       22    17717       429.0
#
#          item_cnt_day
# 5141              2.0
# 8285              2.0
# 13890             1.0
# 13891             1.0
# 13892             1.0
# ...               ...
# ...

# %%
itemsDf[itemsDf.item_id == 17717]
# Out:
#                                   item_name  item_id  item_category_id  \
# 17717  Прием денежных средств для 1С-Онлайн    17717                79
#
#       item_category_name  type  subType
# 17717          Служебные    16       54

# %%
trainDf.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154      999.00           1.0
# 1  03.01.2013               0       25     2552      899.00           1.0
# 2  05.01.2013               0       25     2552      899.00          -1.0
# 3  06.01.2013               0       25     2554     1709.05           1.0
# 4  15.01.2013               0       25     2555     1099.00           1.0

# %% [markdown]
# Translate to Acceptance of funds for 1C-Online

# %%
fig = plt.figure(figsize=(24,24))
trainDf.groupby("date").item_cnt_day.sum().plot()

# %% [markdown]
# daily sales seems quite stationary

# %%
datetimeDf = trainDf.date.str.split(".", expand = True)
datetimeDf.columns = ["day", "month", "year"]
trainDf = trainDf.join(datetimeDf)
trainDf
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# ...             ...             ...      ...      ...         ...
# 2935844  10.10.2015              33       25     7409      299.00
# 2935845  09.10.2015              33       25     7460      299.00
# 2935846  14.10.2015              33       25     7459      349.00
# 2935847  22.10.2015              33       25     7440      299.00
# 2935848  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day day month  year
# 0                 1.0  02    01  2013
# 1                 1.0  03    01  2013
# 2                -1.0  05    01  2013
# ...

# %%
trainDf.groupby(["year", "month"]).item_cnt_day.sum().plot()

# %%
trainDf[trainDf.shop_id == 50].groupby(["year", "month"]).item_cnt_day.sum().plot()

# %%
trainDf.loc[trainDf.shop_id == 0,]
# Out:
#               date  date_block_num  shop_id  item_id  item_price  \
# 37589   12.01.2013               0        0    11059        73.0
# 37590   22.01.2013               0        0    11059        73.0
# 37591   26.01.2013               0        0    11059        73.0
# 37592   12.01.2013               0        0    11347       170.0
# 37593   22.01.2013               0        0    11347       170.0
# ...            ...             ...      ...      ...         ...
# 183257  22.02.2013               1        0    13460      1228.0
# 183258  21.02.2013               1        0    13460      1228.0
# 183259  20.02.2013               1        0    13460      1228.0
# 183260  17.02.2013               1        0    13460      1228.0
# 183261  16.02.2013               1        0    12607        76.0
#
#         item_cnt_day day month  year
# 37589            1.0  12    01  2013
# 37590            1.0  22    01  2013
# 37591            1.0  26    01  2013
# ...

# %% [markdown]
# daily sales per shop

# %%
salesDf = trainDf.groupby(["shop_id", "date"]).item_cnt_day.sum().unstack().T.sort_index()
salesDf.index = pd.to_datetime(salesDf.index)
salesDf.sort_index(inplace = True)
fig = plt.figure(figsize = (64,64))
sns.heatmap(salesDf.corr(), vmin=0, vmax=1)

# %%
# Якутск Орджоникидзе, 56
trainDf.loc[trainDf.shop_id == 0, 'shop_id'] = 57
testDf.loc[testDf.shop_id == 0, 'shop_id'] = 57
# Якутск ТЦ "Центральный"
trainDf.loc[trainDf.shop_id == 1, 'shop_id'] = 58
testDf.loc[testDf.shop_id == 1, 'shop_id'] = 58
# Жуковский ул. Чкалова 39м²
trainDf.loc[trainDf.shop_id == 10, 'shop_id'] = 11
testDf.loc[testDf.shop_id == 10, 'shop_id'] = 11

# %% [markdown]
# engineer shopDf, since each shop name begins with city name, and it might provide important clues to trend

# %%
shopDf["city_code"] = shopDf.shop_name.str.split(" ").apply(lambda x: x[0].strip("!"))
shopDf.city_code.value_counts().plot.bar()
plt.title("City vs Number of shops")
# Out:
# Text(0.5,1,'City vs Number of shops')

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
# shopDf.city_code.tolist()
shopDf.city_code = le.fit_transform(shopDf.city_code.tolist())
shopDf
# Out:
#                                           shop_name  shop_id  city_code
# 0                     !Якутск Орджоникидзе, 56 фран        0         29
# 1                     !Якутск ТЦ "Центральный" фран        1         29
# 2                                  Адыгея ТЦ "Мега"        2          0
# 3                    Балашиха ТРК "Октябрь-Киномир"        3          1
# 4                          Волжский ТЦ "Волга Молл"        4          2
# 5                            Вологда ТРЦ "Мармелад"        5          3
# 6                        Воронеж (Плехановская, 13)        6          4
# 7                            Воронеж ТРЦ "Максимир"        7          4
# 8                      Воронеж ТРЦ Сити-Парк "Град"        8          4
# 9                                 Выездная Торговля        9          5
# 10                       Жуковский ул. Чкалова 39м?       10          6
# 11                       Жуковский ул. Чкалова 39м²       11          6
# ...

# %%
itemsCatDf["type"] = itemsCatDf.item_category_name.str.split("-").apply(lambda x: x[0].strip())
itemsCatDf["subType"] = itemsCatDf.item_category_name.str.split("-").apply(lambda x: x[1].strip() if len(x) > 1 else x[0].strip())

# %%
sns.countplot(itemsCatDf.type)
plt.yticks(np.arange(0,14,1))
# Out:
# ([<matplotlib.axis.YTick at 0x7f7641579048>,
# ...
#  <a list of 14 Text yticklabel objects>)

# %%
countDf = itemsCatDf.type.value_counts()
len(countDf[countDf == 1])/ len(countDf)
# Out:
# 0.45

# %% [markdown]
# Almost half of category only have 1 sub type

# %%
sns.countplot(itemsCatDf.subType)

# %%
itemsCatDf["type"] = le.fit_transform(itemsCatDf["type"])
itemsCatDf["subType"] = le.fit_transform(itemsCatDf["subType"])

# %%
trainDf.loc[trainDf.item_price == -1]
# Out:
#               date  date_block_num  shop_id  item_id  item_price  \
# 484683  15.05.2013               4       32     2973        -1.0
#
#         item_cnt_day day month  year
# 484683           1.0  15    05  2013

# %% [markdown]
# There's a negative price, I am gonna just replace it with the mode value of the (shop_id, item_id) combination

# %%
trainDf[(trainDf.item_id == 2973) & (trainDf.shop_id == 32)]
# Out:
#               date  date_block_num  shop_id  item_id  item_price  \
# 67427   29.01.2013               0       32     2973      2499.0
# 67428   25.01.2013               0       32     2973      2499.0
# 67429   22.01.2013               0       32     2973      2499.0
# 67430   21.01.2013               0       32     2973      2499.0
# 67431   18.01.2013               0       32     2973      2499.0
# 67432   17.01.2013               0       32     2973      2499.0
# 67433   15.01.2013               0       32     2973      2499.0
# 187844  05.02.2013               1       32     2973      2499.0
# 187845  14.02.2013               1       32     2973      2499.0
# 484682  23.05.2013               4       32     2973      1249.0
# 484683  15.05.2013               4       32     2973        -1.0
# 484684  06.05.2013               4       32     2973      2499.0
# 555026  05.06.2013               5       32     2973      1249.5
#
#         item_cnt_day day month  year
# ...

# %%
mode = trainDf[(trainDf.item_id == 2973) & (trainDf.shop_id == 32)].item_price.mode().item()
trainDf.loc[trainDf.item_price == -1, "item_price"] = mode
trainDf.loc[trainDf.item_price == -1]
# Out:
# /home/deploy/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: `item` has been deprecated and will be removed in a future version
#   """Entry point for launching an IPython kernel.
# Empty DataFrame
# Columns: [date, date_block_num, shop_id, item_id, item_price, item_cnt_day, day, month, year]
# Index: []

# %%
price_fluc = trainDf.groupby(["shop_id", "item_id"]).item_price.std()
price_fluc[price_fluc == price_fluc.max()]
# Out:
# shop_id  item_id
# 31       12118      7416.843028
# Name: item_price, dtype: float64

# %%
price_fluc.sort_values(ascending = False)
# Out:
# shop_id  item_id
# 31       12118      7416.843028
# 42       13403      7093.612220
# 16       7982       6716.807314
# 46       7982       6660.828987
# 44       7938       6499.725533
#                        ...
# 59       22118              NaN
#          22144              NaN
#          22153              NaN
#          22154              NaN
#          22155              NaN
# Name: item_price, Length: 418909, dtype: float64

# %%
most_fluc_item = trainDf[(trainDf.shop_id == 31) & (trainDf.item_id == 12118)]
most_fluc_item
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 2225009  29.12.2014              23       31    12118     15001.0
# 2541715  20.03.2015              26       31    12118     25490.0
#
#          item_cnt_day day month  year
# 2225009           1.0  29    12  2014
# 2541715           1.0  20    03  2015

# %%
random_item = trainDf[(trainDf.shop_id == 42) & (trainDf.item_id == 13403)]
random_item
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 2885692  23.10.2015              33       42    13403     42990.0
# 2885693  25.10.2015              33       42    13403     28992.0
# 2885694  29.10.2015              33       42    13403     37991.0
#
#          item_cnt_day day month  year
# 2885692           1.0  23    10  2015
# 2885693           1.0  25    10  2015
# 2885694           2.0  29    10  2015

# %%
random_item = trainDf[(trainDf.shop_id == 16) & (trainDf.item_id == 7982)]
random_item
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 2272999  20.12.2014              23       16     7982     15092.0
# 2686917  23.06.2015              29       16     7982     24591.0
#
#          item_cnt_day day month  year
# 2272999           1.0  20    12  2014
# 2686917           1.0  23    06  2015

# %%
random_item = trainDf[(trainDf.shop_id == 46) & (trainDf.item_id == 7982)]
random_item
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 2206147  20.12.2014              23       46     7982     15092.0
# 2206148  27.12.2014              23       46     7982     17001.0
# 2484503  20.03.2015              26       46     7982     25490.0
# 2484538  28.03.2015              26       46     7982     30990.0
# 2775586  15.08.2015              31       46     7982     25990.0
#
#          item_cnt_day day month  year
# 2206147           2.0  20    12  2014
# 2206148           1.0  27    12  2014
# 2484503           1.0  20    03  2015
# 2484538           1.0  28    03  2015
# 2775586           1.0  15    08  2015

# %% [markdown]
# just a random look seems that price has a slight effect on demand

# %%
testDf
# Out:
#             ID  shop_id  item_id
# 0            0        5     5037
# 1            1        5     5320
# 2            2        5     5233
# 3            3        5     5232
# 4            4        5     5268
# ...        ...      ...      ...
# 214195  214195       45    18454
# 214196  214196       45    16188
# 214197  214197       45    15757
# 214198  214198       45    19648
# 214199  214199       45      969
#
# [214200 rows x 3 columns]

# %%
itemsCatDf
# Out:
#            item_category_name  item_category_id  type  subType
# 0     PC - Гарнитуры/Наушники                 0     0       29
# 1            Аксессуары - PS2                 1     1        9
# 2            Аксессуары - PS3                 2     1       10
# 3            Аксессуары - PS4                 3     1       11
# 4            Аксессуары - PSP                 4     1       13
# ..                        ...               ...   ...      ...
# 79                  Служебные                79    16       54
# 80         Служебные - Билеты                80    16       25
# 81    Чистые носители (шпиль)                81    17       62
# 82  Чистые носители (штучные)                82    18       63
# 83           Элементы питания                83    19       64
#
# [84 rows x 4 columns]

# %%
shopDf.shop_name.str.split(" ")
# Out:
# 0                    [!Якутск, Орджоникидзе,, 56, фран]
# 1                    [!Якутск, ТЦ, "Центральный", фран]
# 2                                  [Адыгея, ТЦ, "Мега"]
# 3                    [Балашиха, ТРК, "Октябрь-Киномир"]
# 4                         [Волжский, ТЦ, "Волга, Молл"]
# 5                            [Вологда, ТРЦ, "Мармелад"]
# 6                        [Воронеж, (Плехановская,, 13)]
# 7                            [Воронеж, ТРЦ, "Максимир"]
# 8                     [Воронеж, ТРЦ, Сити-Парк, "Град"]
# 9                                  [Выездная, Торговля]
# 10                      [Жуковский, ул., Чкалова, 39м?]
# 11                      [Жуковский, ул., Чкалова, 39м²]
# 12                               [Интернет-магазин, ЧС]
# 13                              [Казань, ТЦ, "Бехетле"]
# 14                         [Казань, ТЦ, "ПаркХаус", II]
# 15                            [Калуга, ТРЦ, "XXI, век"]
# 16                                 [Коломна, ТЦ, "Рио"]
# ...

# %% [markdown]
# Did some google translate, the second item and beyonf doesnt mean much in the adress

# %% [markdown]
# # Prepare training set
# Ok, now I can prepare training set

# %%
trainDf = pd.read_csv("sales_train.csv")
print (trainDf.columns)
trainDf.head()
# Out:
# Index(['date', 'date_block_num', 'shop_id', 'item_id', 'item_price',
#        'item_cnt_day'],
#       dtype='object')
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154      999.00           1.0
# 1  03.01.2013               0       25     2552      899.00           1.0
# 2  05.01.2013               0       25     2552      899.00          -1.0
# 3  06.01.2013               0       25     2554     1709.05           1.0
# 4  15.01.2013               0       25     2555     1099.00           1.0

# %%
datetimeDf = trainDf.date.str.split(".", expand = True)
datetimeDf.columns = ["day", "month", "year"]
trainDf = trainDf.join(datetimeDf)
trainDf
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# ...             ...             ...      ...      ...         ...
# 2935844  10.10.2015              33       25     7409      299.00
# 2935845  09.10.2015              33       25     7460      299.00
# 2935846  14.10.2015              33       25     7459      349.00
# 2935847  22.10.2015              33       25     7440      299.00
# 2935848  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day day month  year
# 0                 1.0  02    01  2013
# 1                 1.0  03    01  2013
# 2                -1.0  05    01  2013
# ...

# %%
# trainDf.date = trainDf.date.str.split(".").apply(lambda x: ".".join(x[1:]))
trainDf["revenue"] = trainDf.item_price * trainDf.item_cnt_day
trainDf
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# ...             ...             ...      ...      ...         ...
# 2935844  10.10.2015              33       25     7409      299.00
# 2935845  09.10.2015              33       25     7460      299.00
# 2935846  14.10.2015              33       25     7459      349.00
# 2935847  22.10.2015              33       25     7440      299.00
# 2935848  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day day month  year  revenue
# 0                 1.0  02    01  2013   999.00
# 1                 1.0  03    01  2013   899.00
# ...

# %%
trainDf.drop(["item_price", "day"], axis = 1, inplace = True)

# %%
trainDf.drop(["date"], axis = 1, inplace = True)
trainDf
# Out:
#          date_block_num  shop_id  item_id  item_cnt_day month  year  revenue
# 0                     0       59    22154           1.0    01  2013   999.00
# 1                     0       25     2552           1.0    01  2013   899.00
# 2                     0       25     2552          -1.0    01  2013  -899.00
# 3                     0       25     2554           1.0    01  2013  1709.05
# 4                     0       25     2555           1.0    01  2013  1099.00
# ...                 ...      ...      ...           ...   ...   ...      ...
# 2935844              33       25     7409           1.0    10  2015   299.00
# 2935845              33       25     7460           1.0    10  2015   299.00
# 2935846              33       25     7459           1.0    10  2015   349.00
# 2935847              33       25     7440           1.0    10  2015   299.00
# 2935848              33       25     7460           1.0    10  2015   299.00
#
# [2935849 rows x 7 columns]

# %%
trainDf.isnull().sum()
# Out:
# date_block_num    0
# shop_id           0
# item_id           0
# item_cnt_day      0
# month             0
# year              0
# revenue           0
# dtype: int64

# %%
trainDf.month = trainDf.month.astype(int)
trainDf.year = trainDf.year.astype(int)

# %%
trainDf.astype({'month': int, 'year': int})
trainDf.groupby(["date_block_num", "shop_id", "item_id"]).agg({"item_cnt_day": 'sum', 
                                                               "month": "mean",
                                                              "year": "mean", 
                                                              "revenue": "sum"})
# Out:
#                                 item_cnt_day  month  year  revenue
# date_block_num shop_id item_id
# 0              0       32                6.0      1  2013   1326.0
#                        33                3.0      1  2013   1041.0
#                        35                1.0      1  2013    247.0
#                        43                1.0      1  2013    221.0
#                        51                2.0      1  2013    257.0
# ...                                      ...    ...   ...      ...
# 33             59      22087             6.0     10  2015    714.0
#                        22088             2.0     10  2015    238.0
#                        22091             1.0     10  2015    179.0
#                        22100             1.0     10  2015    629.0
#                        22102             1.0     10  2015   1250.0
#
# [1609124 rows x 4 columns]

# %%
# trainDf.drop("date_block_num", axis = 1, inplace = True)

# %%
trainDf
# Out:
#          date_block_num  shop_id  item_id  item_cnt_day  month  year  revenue
# 0                     0       59    22154           1.0      1  2013   999.00
# 1                     0       25     2552           1.0      1  2013   899.00
# 2                     0       25     2552          -1.0      1  2013  -899.00
# 3                     0       25     2554           1.0      1  2013  1709.05
# 4                     0       25     2555           1.0      1  2013  1099.00
# ...                 ...      ...      ...           ...    ...   ...      ...
# 2935844              33       25     7409           1.0     10  2015   299.00
# 2935845              33       25     7460           1.0     10  2015   299.00
# 2935846              33       25     7459           1.0     10  2015   349.00
# 2935847              33       25     7440           1.0     10  2015   299.00
# 2935848              33       25     7460           1.0     10  2015   299.00
#
# [2935849 rows x 7 columns]

# %%
trainDf= trainDf.groupby(["date_block_num", "shop_id", "item_id", "month", "year"]).agg({"item_cnt_day": "sum", "revenue": "sum"}).reset_index()
trainDf
# Out:
#          date_block_num  shop_id  item_id  month  year  item_cnt_day  revenue
# 0                     0        0       32      1  2013           6.0   1326.0
# 1                     0        0       33      1  2013           3.0   1041.0
# 2                     0        0       35      1  2013           1.0    247.0
# 3                     0        0       43      1  2013           1.0    221.0
# 4                     0        0       51      1  2013           2.0    257.0
# ...                 ...      ...      ...    ...   ...           ...      ...
# 1609119              33       59    22087     10  2015           6.0    714.0
# 1609120              33       59    22088     10  2015           2.0    238.0
# 1609121              33       59    22091     10  2015           1.0    179.0
# 1609122              33       59    22100     10  2015           1.0    629.0
# 1609123              33       59    22102     10  2015           1.0   1250.0
#
# [1609124 rows x 7 columns]

# %%
itemsCatDf.head()
# Out:
#         item_category_name  item_category_id  type  subType
# 0  PC - Гарнитуры/Наушники                 0     0       29
# 1         Аксессуары - PS2                 1     1        9
# 2         Аксессуары - PS3                 2     1       10
# 3         Аксессуары - PS4                 3     1       11
# 4         Аксессуары - PSP                 4     1       13

# %%
len(trainDf.item_id.unique())
# Out:
# 21807

# %%
shopDf.head()
# Out:
#                         shop_name  shop_id  city_code
# 0   !Якутск Орджоникидзе, 56 фран        0         29
# 1   !Якутск ТЦ "Центральный" фран        1         29
# 2                Адыгея ТЦ "Мега"        2          0
# 3  Балашиха ТРК "Октябрь-Киномир"        3          1
# 4        Волжский ТЦ "Волга Молл"        4          2

# %%
trainDf = trainDf.merge(shopDf, on="shop_id", how="left")
trainDf
# Out:
#          date_block_num  shop_id  item_id  month  year  item_cnt_day  revenue  \
# 0                     0        0       32      1  2013           6.0   1326.0
# 1                     0        0       33      1  2013           3.0   1041.0
# 2                     0        0       35      1  2013           1.0    247.0
# 3                     0        0       43      1  2013           1.0    221.0
# 4                     0        0       51      1  2013           2.0    257.0
# ...                 ...      ...      ...    ...   ...           ...      ...
# 1609119              33       59    22087     10  2015           6.0    714.0
# 1609120              33       59    22088     10  2015           2.0    238.0
# 1609121              33       59    22091     10  2015           1.0    179.0
# 1609122              33       59    22100     10  2015           1.0    629.0
# 1609123              33       59    22102     10  2015           1.0   1250.0
#
# ...

# %%
itemsDf = itemsDf.merge(itemsCatDf, on="item_category_id", how="left", suffixes=("",""))
itemsDf
# Out:
#                                                item_name  item_id  \
# 0              ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D        0
# 1      !ABBYY FineReader 12 Professional Edition Full...        1
# 2          ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
# 3        ***ГОЛУБАЯ ВОЛНА  (Univ)                      D        3
# 4            ***КОРОБКА (СТЕКЛО)                       D        4
# ...                                                  ...      ...
# 22165             Ядерный титбит 2 [PC, Цифровая версия]    22165
# 22166    Язык запросов 1С:Предприятия  [Цифровая версия]    22166
# 22167  Язык запросов 1С:Предприятия 8 (+CD). Хрустале...    22167
# 22168                                Яйцо для Little Inu    22168
# 22169                      Яйцо дракона (Игра престолов)    22169
#
#        item_category_id                    item_category_name  type  subType
# 0                    40                            Кино - DVD    11        4
# ...

# %%
trainDf = trainDf.merge(itemsDf, on="item_id", how="left", suffixes=("",""))
trainDf
# Out:
#          date_block_num  shop_id  item_id  month  year  item_cnt_day  revenue  \
# 0                     0        0       32      1  2013           6.0   1326.0
# 1                     0        0       33      1  2013           3.0   1041.0
# 2                     0        0       35      1  2013           1.0    247.0
# 3                     0        0       43      1  2013           1.0    221.0
# 4                     0        0       51      1  2013           2.0    257.0
# ...                 ...      ...      ...    ...   ...           ...      ...
# 1609119              33       59    22087     10  2015           6.0    714.0
# 1609120              33       59    22088     10  2015           2.0    238.0
# 1609121              33       59    22091     10  2015           1.0    179.0
# 1609122              33       59    22100     10  2015           1.0    629.0
# 1609123              33       59    22102     10  2015           1.0   1250.0
#
# ...

# %%
trainDf.drop(["shop_name", "item_name", "item_category_name", "type"], axis = 1, inplace=True)

# %% [markdown]
# # TODO
#
# should have some lagging features.
# - [] Rename item_nt_day to month
# - [] Previous month revenue,item_cnt_month for that shop, item combo
# - [] Not every item has previous revenue, so maybe same item_category_id revenue
# - [] 0 for NaN

# %%
trainDf.rename(columns = {"item_cnt_day": "item_cnt_month"}, inplace = True)
trainDf
# Out:
#          date_block_num  shop_id  item_id  month  year  item_cnt_month  \
# 0                     0        0       32      1  2013             6.0
# 1                     0        0       33      1  2013             3.0
# 2                     0        0       35      1  2013             1.0
# 3                     0        0       43      1  2013             1.0
# 4                     0        0       51      1  2013             2.0
# ...                 ...      ...      ...    ...   ...             ...
# 1609119              33       59    22087     10  2015             6.0
# 1609120              33       59    22088     10  2015             2.0
# 1609121              33       59    22091     10  2015             1.0
# 1609122              33       59    22100     10  2015             1.0
# 1609123              33       59    22102     10  2015             1.0
#
#          revenue  city_code  item_category_id  subType
# 0         1326.0         29                40        4
# ...

# %%
def lag_shift(df, columns = list, lag = int):
    '''
    column: The column to shift
    lag: Number of month to shift
    '''
    tmpDf = df[["date_block_num", "shop_id", "item_id", *columns]]
    tmpDf.date_block_num = tmpDf.date_block_num + 1
    print (tmpDf.head())
    df = df.merge(tmpDf, on="date_block_num", how="left")
    
    
    return df
#     df[f"{column}_shift_{lag}"] = 
lag_shift(trainDf.head(100000), ["item_cnt_month"], 1)
# Out:
#    date_block_num  shop_id  item_id  item_cnt_month
# 0               1        0       32             6.0
# 1               1        0       33             3.0
# 2               1        0       35             1.0
# 3               1        0       43             1.0
# 4               1        0       51             2.0
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-86-09d55f987c11> in <module>
#      12     return df
#      13 #     df[f"{column}_shift_{lag}"] =
# ---> 14 lag_shift(trainDf.head(100000), ["item_cnt_month"], 1)
#      15
#
# <ipython-input-86-09d55f987c11> in lag_shift(df, columns, lag)
#       7     tmpDf.date_block_num = tmpDf.date_block_num + 1
#       8     print (tmpDf.head())
# ----> 9     df = df.merge(tmpDf, on="date_block_num", how="left")
#      10
#      11
#
# ...

# %%
from itertools import product
matrix = []
cols = ['date_block_num','shop_id','item_id']
for i in range(34):
    sales = trainDf[trainDf.date_block_num==i]
    matrix.append(np.array(list(product([i], sales.shop_id.unique(), sales.item_id.unique())), dtype='int16'))
    
matrix = pd.DataFrame(np.vstack(matrix), columns=cols)
matrix['date_block_num'] = matrix['date_block_num'].astype(np.int8)
matrix['shop_id'] = matrix['shop_id'].astype(np.int8)
matrix['item_id'] = matrix['item_id'].astype(np.int16)
matrix.sort_values(cols,inplace=True)

# %%
matrix.head()
# Out:
#       date_block_num  shop_id  item_id
# 6277               0        0       19
# 2385               0        0       27
# 5155               0        0       28
# 2386               0        0       29
# 0                  0        0       32

# %%
group = trainDf.groupby(['date_block_num','shop_id','item_id']).agg({'item_cnt_day': ['sum']})
group.columns = ['item_cnt_month']
group.reset_index(inplace=True)

matrix = pd.merge(matrix, group, on=cols, how='left')
matrix['item_cnt_month'] = (matrix['item_cnt_month']
                                .fillna(0)
                                .clip(0,20) # NB clip target here
                                .astype(np.float16))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-74-d4d893713904> in <module>
# ----> 1 group = trainDf.groupby(['date_block_num','shop_id','item_id']).agg({'item_cnt_day': ['sum']})
#       2 group.columns = ['item_cnt_month']
#       3 group.reset_index(inplace=True)
#       4
#       5 matrix = pd.merge(matrix, group, on=cols, how='left')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, arg, *args, **kwargs)
#    1453     @Appender(_shared_docs["aggregate"])
#    1454     def aggregate(self, arg=None, *args, **kwargs):
# -> 1455         return super().aggregate(arg, *args, **kwargs)
#    1456
#    1457     agg = aggregate
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, func, *args, **kwargs)
#     227         func = _maybe_mangle_lambdas(func)
#     228
# ...

# %%
matrix.desribe()
